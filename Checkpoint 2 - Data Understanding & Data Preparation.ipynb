# %% [markdown]
# # **LIBRARY**

# %%
import pandas as pd

# %% [markdown]
# # **MEMBACA DATA**

# %%
df = pd.read_csv("/content/academic_performance_dataset_V2.csv")

df
# Out:
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0     42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1     70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2     31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3     63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4     30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
# ...     ...       ...     ...   ...   ...      ...      ...      ...      ...
# 3041  64106      PHYG  Female  2013  4.18     4.04     4.23     4.16     4.28
# 3042  96596      PHYG    Male  2013  2.91     2.36     3.35     2.87     3.02
# 3043  64982      PHYG    Male  2013  3.66     3.42     3.83     3.55     3.82
# 3044  27052      PHYG  Female  2014  4.56     4.39     4.70     4.58     4.63
# 3045  65054      PHYG    Male  2014  4.18     4.29     4.43     3.68     4.14
#
#       SGPA
# 0     3.13
# ...

# %% [markdown]
# # **PENGECEKAN STRUKTUR DATA**

# %%
print("Jika ingin menampilkan Beberapa Row Data:")
df.head(10)
# Out:
# Jika ingin menampilkan Beberapa Row Data:
#    ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0  42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1  70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2  31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3  63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4  30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
# 5  51740       BCH    Male  2010  2.97     2.66     2.98     3.28     3.07
# 6  76075       BCH    Male  2010  3.34     3.68     3.00     3.44     3.28
# 7  60888       BCH  Female  2010  2.56     2.30     2.50     2.29     2.77
# 8  43378       BCH    Male  2010  3.76     3.30     3.64     3.88     4.37
# 9  80307       BCH  Female  2010  3.96     3.94     3.89     3.81     4.17
#
#    SGPA
# 0  3.13
# 1  3.02
# 2  2.19
# 3  3.19
# 4  4.24
# 5  3.13
# 6  3.02
# 7  2.68
# 8  3.13
# ...

# %%
print("\nJika ingin menampilkan Keseluruhan Data:")
df
# Out:
# Jika ingin menampilkan Keseluruhan Data:
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0     42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1     70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2     31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3     63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4     30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
# ...     ...       ...     ...   ...   ...      ...      ...      ...      ...
# 3041  64106      PHYG  Female  2013  4.18     4.04     4.23     4.16     4.28
# 3042  96596      PHYG    Male  2013  2.91     2.36     3.35     2.87     3.02
# 3043  64982      PHYG    Male  2013  3.66     3.42     3.83     3.55     3.82
# 3044  27052      PHYG  Female  2014  4.56     4.39     4.70     4.58     4.63
# ...

# %%
print("\nMenampilkan 5 baris pertama dengan df.head():")
df.head()
# Out:
# Menampilkan 5 baris pertama dengan df.head():
#    ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0  42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1  70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2  31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3  63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4  30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
#
#    SGPA
# 0  3.13
# 1  3.02
# 2  2.19
# 3  3.19
# 4  4.24

# %%
print("\nMenampilkan 5 baris terakhir dengan df.tail():")
df.tail()
# Out:
# Menampilkan 5 baris terakhir dengan df.tail():
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 3041  64106      PHYG  Female  2013  4.18     4.04     4.23     4.16     4.28
# 3042  96596      PHYG    Male  2013  2.91     2.36     3.35     2.87     3.02
# 3043  64982      PHYG    Male  2013  3.66     3.42     3.83     3.55     3.82
# 3044  27052      PHYG  Female  2014  4.56     4.39     4.70     4.58     4.63
# 3045  65054      PHYG    Male  2014  4.18     4.29     4.43     3.68     4.14
#
#       SGPA
# 3041  3.20
# 3042  2.03
# 3043  3.33
# 3044  3.52
# 3045  4.10

# %%
print("\nMenampilkan ringkasan informasi dataset dengan df.info():")
df.info()
# Out:
# Menampilkan ringkasan informasi dataset dengan df.info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3046 entries, 0 to 3045
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID No      3046 non-null   int64
#  1   Prog Code  3046 non-null   object
#  2   Gender     3046 non-null   object
#  3   YoG        3046 non-null   int64
#  4   CGPA       3046 non-null   float64
#  5   CGPA100    3046 non-null   float64
#  6   CGPA200    3046 non-null   float64
#  7   CGPA300    3046 non-null   float64
#  8   CGPA400    3046 non-null   float64
#  9   SGPA       3046 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 238.1+ KB

# %%
print("\nMenampilkan jumlah baris dan kolom dengan df.shape:")
print(df.shape)
# Out:
# Menampilkan jumlah baris dan kolom dengan df.shape:
# (3046, 10)

# %%
print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
print(df.dtypes)
# Out:
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# ID No          int64
# Prog Code     object
# Gender        object
# YoG            int64
# CGPA         float64
# CGPA100      float64
# CGPA200      float64
# CGPA300      float64
# CGPA400      float64
# SGPA         float64
# dtype: object

# %%
df.describe()
# Out:
#               ID No          YoG         CGPA      CGPA100      CGPA200  \
# count   3046.000000  3046.000000  3046.000000  3046.000000  3046.000000
# mean   61082.817466  2012.183848     3.494813     3.636106     3.321687
# std    21256.532751     1.329104     0.691614     0.679256     0.782473
# min    23462.000000  2010.000000     1.520000     1.570000     1.170000
# 25%    42654.250000  2011.000000     3.000000     3.180000     2.760000
# 50%    61759.000000  2012.000000     3.560000     3.690000     3.340000
# 75%    79236.250000  2013.000000     4.010000     4.150000     3.920000
# max    97563.000000  2014.000000     4.990000     5.000000     5.000000
#
#            CGPA300      CGPA400         SGPA
# count  3046.000000  3046.000000  3046.000000
# mean      3.418578     3.532508     3.119645
# std       0.858518     0.802228     0.616151
# min       0.630000     0.000000     1.460000
# 25%       2.810000     3.000000     2.660000
# 50%       3.510000     3.620000     3.060000
# ...

# %%
kolom_tertentu = "CGPA100"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'CGPA100' dengan df['CGPA100'].value_counts():
# CGPA100
# 4.00    44
# 3.98    40
# 4.13    37
# 4.11    37
# 4.02    36
#         ..
# 1.84     1
# 1.70     1
# 2.10     1
# 2.15     1
# 1.80     1
# Name: count, Length: 300, dtype: int64

# %%
print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))
# Out:
# Menghitung rata-rata dengan df.mean():
# ID No      61082.817466
# YoG         2012.183848
# CGPA           3.494813
# CGPA100        3.636106
# CGPA200        3.321687
# CGPA300        3.418578
# CGPA400        3.532508
# SGPA           3.119645
# dtype: float64

# %%
print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))
# Out:
# Menghitung median dengan df.median():
# ID No      61759.00
# YoG         2012.00
# CGPA           3.56
# CGPA100        3.69
# CGPA200        3.34
# CGPA300        3.51
# CGPA400        3.62
# SGPA           3.06
# dtype: float64

# %%
print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))
# Out:
# Menghitung standar deviasi dengan df.std():
# ID No      21256.532751
# YoG            1.329104
# CGPA           0.691614
# CGPA100        0.679256
# CGPA200        0.782473
# CGPA300        0.858518
# CGPA400        0.802228
# SGPA           0.616151
# dtype: float64

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#             ID No       YoG      CGPA   CGPA100   CGPA200   CGPA300   CGPA400  \
# ID No    1.000000 -0.010005 -0.008673  0.005013  0.023332 -0.013209 -0.029279
# YoG     -0.010005  1.000000  0.040251  0.100879 -0.091117  0.061340  0.073587
# CGPA    -0.008673  0.040251  1.000000  0.792364  0.910676  0.906560  0.886461
# CGPA100  0.005013  0.100879  0.792364  1.000000  0.703889  0.598649  0.590058
# CGPA200  0.023332 -0.091117  0.910676  0.703889  1.000000  0.792281  0.736333
# CGPA300 -0.013209  0.061340  0.906560  0.598649  0.792281  1.000000  0.810704
# CGPA400 -0.029279  0.073587  0.886461  0.590058  0.736333  0.810704  1.000000
# SGPA     0.001796 -0.088181  0.379805  0.434993  0.344725  0.290820  0.303924
#
#              SGPA
# ID No    0.001796
# YoG     -0.088181
# CGPA     0.379805
# CGPA100  0.434993
# CGPA200  0.344725
# CGPA300  0.290820
# CGPA400  0.303924
# SGPA     1.000000

# %% [markdown]
# # **DATA CLEANING**

# %% [markdown]
# Data cleaning merupakan proses menghapus atau memodifikasi data yang tidak lengkap, duplikat, tidak akurat, dan salah format. Data-data tersebut dihapus atau dimodifikasi untuk memastikan data yang sedang diolah adalah data berkualitas agar dapat menghasilkan keputusan yang lebih akurat.

# %% [markdown]
# # **MISSING VAALUES**

# %% [markdown]
# Missing Values adalah sebuah kondisi dimana data hilang atau tidak terbaca.

# %% [markdown]
# # **MELIHAT MISSING VALUES**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# ID No        0.0
# Prog Code    0.0
# Gender       0.0
# YoG          0.0
# CGPA         0.0
# CGPA100      0.0
# CGPA200      0.0
# CGPA300      0.0
# CGPA400      0.0
# SGPA         0.0
# dtype: float64

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom Gender

# %%
df[df['Gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID No, Prog Code, Gender, YoG, CGPA, CGPA100, CGPA200, CGPA300, CGPA400, SGPA]
# Index: []

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom CGPA100

# %%
df[df['CGPA100'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID No, Prog Code, Gender, YoG, CGPA, CGPA100, CGPA200, CGPA300, CGPA400, SGPA]
# Index: []

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#            Null Ratio %
# ID No               0.0
# Prog Code           0.0
# Gender              0.0
# YoG                 0.0
# CGPA                0.0
# CGPA100             0.0
# CGPA200             0.0
# CGPA300             0.0
# CGPA400             0.0
# SGPA                0.0

# %% [markdown]
# TIDAK ADA MISSING VALUES DAN JUGA KOLOM KOSONG JADI TIDAK DIATASI.

# %% [markdown]
# # **DUPLICATED VALUES**

# %% [markdown]
# Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %% [markdown]
# # **MELIHAT DUPLICATE VALUES**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID No, Prog Code, Gender, YoG, CGPA, CGPA100, CGPA200, CGPA300, CGPA400, SGPA]
# Index: []

# %% [markdown]
# TIDAK ADA DUPLICATE VALUES JADI TIDAK DIATASI

# %% [markdown]
# # **OUTLIERS**

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# # **MELAKUKAN PENGECEKAN OUTLIERS**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom    Persentase Outliers
# ID No               0.000000
# YoG                 0.000000
# CGPA                0.000000
# CGPA100             0.459619
# CGPA200             0.000000
# CGPA300             0.098490
# CGPA400             0.262640
# SGPA                0.000000

# %% [markdown]
# MENGATASI OUTLIERS DENGAN MALAKUKAN IMPUTASI

# %%
columns_to_impute = ["CGPA100", "CGPA300", "CGPA400"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom    Persentase Outliers
# ID No                    0.0
# YoG                      0.0
# CGPA                     0.0
# CGPA100                  0.0
# CGPA200                  0.0
# CGPA300                  0.0
# CGPA400                  0.0
# SGPA                     0.0

# %% [markdown]
# # **INCOSISTENT VALUE**

# %% [markdown]
# Inconsistent Values adalah sebuah kondisi dimana
# nilai-nilai dalam suatu kolom tidak sesuai format atau
# memiliki tipe data yang berbeda

# %% [markdown]
# # **CONSTRUCT DATA**

# %% [markdown]
# Construct Data merujuk pada kegiatan membangun atau menciptakan fitur (features) baru dari data yang
# ada atau mengubah struktur data agar sesuai dengan kebutuhan analisis atau model data mining yang
# akan digunakan. Kegiatan ini biasa dilakukan dengan memanipulasi data untuk membuat atribut atau
# variabel baru yang dapat meningkatkan pemahaman kita tentang fenomena yang diamati atau
# meningkatkan kinerja model yang akan kita bangun.

# %%
df["avg_CGPA_early"] = (df["CGPA100"] + df["CGPA200"]) / 2

print(df.head())
# Out:
#    ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0  42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1  70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2  31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3  63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4  30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
#
#    SGPA  avg_CGPA_early
# 0  3.13           3.180
# 1  3.02           3.755
# 2  2.19           1.880
# 3  3.19           2.555
# 4  4.24           3.650

# %%
df
# Out:
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0     42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1     70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2     31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3     63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4     30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
# ...     ...       ...     ...   ...   ...      ...      ...      ...      ...
# 3041  64106      PHYG  Female  2013  4.18     4.04     4.23     4.16     4.28
# 3042  96596      PHYG    Male  2013  2.91     2.36     3.35     2.87     3.02
# 3043  64982      PHYG    Male  2013  3.66     3.42     3.83     3.55     3.82
# 3044  27052      PHYG  Female  2014  4.56     4.39     4.70     4.58     4.63
# 3045  65054      PHYG    Male  2014  4.18     4.29     4.43     3.68     4.14
#
#       SGPA  avg_CGPA_early
# ...

# %% [markdown]
# # **DATA REDUCTION**

# %% [markdown]
# Data reduction merupakan teknik yang digunakan dalam data mining untuk mengurangi ukuran dataset
# tetapi tetap menjaga informasi yang penting. Hal ini sangat membantu dalam situasi dimana dataset terlalu
# besar untuk di proses secara efisien, atau situasi dimana dataset memiliki informasi yang tidak relevan atau
# informasi yang berulang-ulang.

# %%
df = df.drop('Gender', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-a3e294885039> in <cell line: 0>()
# ----> 1 df = df.drop('Gender', axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#       ID No Prog Code   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  SGPA  \
# 0     42308       ICE  2010  3.23     2.88     3.48     2.62     2.90  3.13
# 1     70978       BCH  2010  3.58     3.25     4.26     3.37     3.47  3.02
# 2     31602       BCH  2010  2.21     1.78     1.98     1.49     2.51  2.19
# 3     63847       BCH  2010  2.70     2.67     2.44     2.00     2.35  3.19
# 4     30158       BCH  2010  3.88     3.61     3.69     3.63     4.58  4.24
# ...     ...       ...   ...   ...      ...      ...      ...      ...   ...
# 3041  64106      PHYG  2013  4.18     4.04     4.23     4.16     4.28  3.20
# 3042  96596      PHYG  2013  2.91     2.36     3.35     2.87     3.02  2.03
# 3043  64982      PHYG  2013  3.66     3.42     3.83     3.55     3.82  3.33
# 3044  27052      PHYG  2014  4.56     4.39     4.70     4.58     4.63  3.52
# 3045  65054      PHYG  2014  4.18     4.29     4.43     3.68     4.14  4.10
#
#       avg_CGPA_early
# 0              3.180
# ...
